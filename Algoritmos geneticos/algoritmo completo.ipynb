# %%
import pandas as pd
import numpy as np
import random

# %%
def cargar_ficheros():
    
    onlyfiles = [f for f in listdir('Datos') if isfile(join('Datos', f))]

    datos = []

    for fichero in onlyfiles:

         
        df = pd.read_csv(join('Datos', fichero))    
        datos.append(df)

    datos = pd.concat(datos)
    return datos

# %%
def comprobar_homogeneizacion(datos):

 

    long_fechas_unicas = datos.date.unique().shape[0]
    long_isin_unicos = datos.iloc[:,2].unique().shape[0]

    if (long_fechas_unicas * long_isin_unicos == datos.shape[1]) == True:
        print("Los activos están homogeneizados")
        return True
    else:
        print("Los activos NO están homogeneizados")
        return False

# %%
def extraccion_datos(isin, datos):
    
   
    df_intermedio = datos.loc[datos["isin"]==isin,:]

   
    nuevo_df = pd.DataFrame(df_intermedio, columns=["date","nav"])
    

    nuevo_df = nuevo_df.groupby('date').first().reset_index()      
    
    nuevo_df.index = nuevo_df.date  
    nuevo_df.index = pd.to_datetime(nuevo_df.index)    
    del nuevo_df["date"]
    nuevo_df.columns = [isin]
    
    return nuevo_df

# %%
def homogeizar(datos):

    lista_isin = datos.iloc[:,2].unique()

    fechas_posibles = datos.date.unique()
    fechas_posibles.sort()
    fechas_posibles = pd.date_range(fechas_posibles[0], fechas_posibles[-1], freq=BDay())
    datos_ordenados = pd.DataFrame(columns=[""], index = fechas_posibles) 

    for isin in lista_isin:

        print(isin)
        isin_extraido = extraccion_datos(isin, datos)

       
        if (isin_extraido.shape[0] > fechas_posibles.shape[0]*0.7):

            datos_ordenados = pd.concat([datos_ordenados, isin_extraido], axis=1) 

    datos_ordenados = datos_ordenados.drop(columns='')


    dias_eliminar = ~(datos_ordenados.isna().sum(axis=1) > datos_ordenados.shape[1]*0.9)
    datos_ordenados = datos_ordenados.loc[dias_eliminar,:]


    datos_ordenados = datos_ordenados.fillna(method='ffill')

  
    datos_ordenados = datos_ordenados.fillna(method='bfill')

    datos_ordenados.to_pickle("datos_ordenados.pkl")     
    
    return datos_ordenados

# %%
def cargar_datos():

    try:
        datos_ordenados = pd.read_pickle("datos_ordenados.pkl")

    except:
        datos = cargar_ficheros()
        comprobacion = comprobar_homogeneizacion(datos)

        if comprobacion == False:
            datos_ordenados = homogeizar(datos)
            
    return datos_ordenados

# %% [markdown]
# ## Generamos la población inicial

# %%
def asignar_pesos(posicion_cartera, num_sim = 100):

    

    pesos_cartera = np.empty([num_sim, len(posicion_cartera)])

    for sim in range(num_sim):

      
        posiciones_aleatorias = random.sample(range(len(posicion_cartera)), len(posicion_cartera))
        peso_total = 0

        for pos in posiciones_aleatorias:

            if peso_total < 1:

                aleatorio = np.random.random()        

                pesos_cartera[sim, pos] = aleatorio
                peso_total += pesos_cartera[sim, pos]

                if peso_total >= 1:

                    exceso = peso_total - 1
                    pesos_cartera[sim, pos] = pesos_cartera[sim, pos] - exceso
                    peso_total = 1

            else:

                
                pesos_cartera[sim, pos] = 0

        
        if pesos_cartera[sim,:].sum() < 1:

            pesos_cartera[sim,:] = pesos_cartera[sim,:] / pesos_cartera[sim,:].sum()

    return pesos_cartera

# %%
def generar_poblacion_inicial(datos_ordenados, num_act_min = 2, num_act_max = 20):

   

    num_inversores = int(np.ceil((datos_ordenados.shape[1] * 50) / (5 + datos_ordenados.shape[1])))
    num_activos_gen_inicial = np.random.randint(low=num_act_min, high=num_act_max, size=num_inversores)
    lista_posiciones = list()
    
    for inv in range(num_inversores):

        
        
        posicion_cartera = np.random.randint(low=0, high= (datos_ordenados.shape[1]-1), size=num_activos_gen_inicial[inv])
        lista_posiciones.append(posicion_cartera)
           
    return lista_posiciones

# %% [markdown]
# ## Calculamos la función de fitness

# %%
def calcular_fitness(datos_ordenados, posiciones):
    
    
    
    datos = datos_ordenados.iloc[:,list(posiciones)]

    # Calculamos la rentabilidad de los activos
    rent_activos = np.log(datos).diff() 
    rent_activos = rent_activos.iloc[1:,:]

    
    matriz_correlaciones = rent_activos.corr()

    
    matriz_covarianzas = rent_activos.cov()
    matriz_covarianzas = matriz_covarianzas.to_numpy(dtype='float') 


    precio_inicial = datos.iloc[0,:]
    precio_final = datos.iloc[-1,:]
    rentabilidad_diaria = np.log(precio_final / precio_inicial) / datos.shape[0]

    # Sacamos la matriz de pesos para cada cartera
    matriz_pesos = asignar_pesos(posiciones)
    
    
    auxiliar = rentabilidad_diaria.values * matriz_pesos
    rentabilidad_cartera = auxiliar.sum(axis=1)

   
    auxiliar = np.dot(matriz_pesos, matriz_covarianzas) # Reutilizo la matriz auxiliar con otro propósito para no sobrecargar la RAM
    riesgo_cartera = pow((auxiliar * matriz_pesos).sum(axis=1), 0.5)

    
    posiciones_0entre0 = (rentabilidad_cartera==0) * (riesgo_cartera==0)    
    riesgo_cartera[posiciones_0entre0] = 0.0000001
    eficiencia_cartera = rentabilidad_cartera / riesgo_cartera
    
    
    posicion_cartera_eficiente = np.where(eficiencia_cartera == eficiencia_cartera.max())
    eficiencia_cartera = eficiencia_cartera.max()
    pesos_cartera_eficiente = matriz_pesos[posicion_cartera_eficiente,:]
        
    return eficiencia_cartera, pesos_cartera_eficiente

# %% [markdown]
# ## Selección de padres

# %%
def seleccion_padres(lista_fitness):

    
    fitness_normalizado = np.asarray(lista_fitness)
    fitness_normalizado = (fitness_normalizado - fitness_normalizado.min()) / (fitness_normalizado.max() - fitness_normalizado.min())

    
    orden_aleatorio = random.sample(range(len(fitness_normalizado)), len(fitness_normalizado))

    padres_seleccionados = list()
    for candidato in orden_aleatorio:

        
        aleatorio = np.random.random() 

        if fitness_normalizado[candidato] > aleatorio:

            padres_seleccionados.append(candidato)

            if len(padres_seleccionados) == 2:

                break
   
    return padres_seleccionados

# %% [markdown]
# ## Cruzamiento y mutación

# %%
def cruzamiento(datos_ordenados, lista_posiciones, lista_pesos_carteras_fitness, padres_seleccionados, umbral = 0.4, num_act_max = 20):

    '''
    Las técnicas habituales de cruzamiento en algoritmos genéticos (N-puntos, segmentación, uniforme y aleatorio) no parecen apropiadas para resolver este problema
    Queremos generar un sitema que cruce la información genética de los padres, permitiendo que el tamaño (número de activos) del hijo difiera del de los padres (sin tener que ser forzosamente mayor)
    EL sistema de cruzamiento debe centrarse en la selección de activos y no en los pesos. Dado que los pesos serán calculados durante la función de fitness
    Hemos usado en las funciones previas dos de los elementos más importantes para resolver el problema: pesos y eficiencia (relación rentabilidad riesgo)
    Para hacer el cruzamiento, debemos usar el último elemento importante que queda: la correlación (medida normalizada de la covarianza)

    '''

   
    posiciones_activos_con_peso_papa = np.where(lista_pesos_carteras_fitness[padres_seleccionados[0]] != 0)
    posiciones_activos_con_peso_mama = np.where(lista_pesos_carteras_fitness[padres_seleccionados[1]] != 0)

    activos_con_peso_papa = lista_posiciones[padres_seleccionados[0]][posiciones_activos_con_peso_papa[2]]
    activos_con_peso_mama = lista_posiciones[padres_seleccionados[1]][posiciones_activos_con_peso_mama[2]]


    activos_con_peso = np.unique(np.append(activos_con_peso_papa, activos_con_peso_mama))
    activos_con_peso

    
    datos = datos_ordenados.iloc[:,activos_con_peso]

    precio_inicial = datos.iloc[0,:]
    precio_final = datos.iloc[-1,:]
    rent_global_activos = np.log(precio_final / precio_inicial) 

    riesgo_global_activos = np.std(datos, axis=0)

    eficiencia_global_activos = rent_global_activos / riesgo_global_activos

  
    rent_activos = np.log(datos).diff() 
    rent_activos = rent_activos.iloc[1:,:]

    matriz_correlaciones = rent_activos.corr()

   

    relaciones_a_analizar = matriz_correlaciones[np.logical_and(matriz_correlaciones > umbral, matriz_correlaciones != 1)]
    relaciones_a_analizar = np.where(matriz_correlaciones == relaciones_a_analizar)

    if len(relaciones_a_analizar[0]) > 0:

       
        activos_a_eliminar = list()

        for pos in range(len(relaciones_a_analizar[0])):

            if eficiencia_global_activos.iloc[relaciones_a_analizar[0][pos]] > eficiencia_global_activos.iloc[relaciones_a_analizar[1][pos]]:

                activos_a_eliminar.append(relaciones_a_analizar[1][pos])

            else:

                activos_a_eliminar.append(relaciones_a_analizar[0][pos])

        activos_a_eliminar = list(set(activos_a_eliminar))    
        activos_con_peso = np.delete(activos_con_peso, activos_a_eliminar)

    
    nuevos_activos = mutacion(datos_ordenados, activos_con_peso, num_act_max = 20)

    activos_heredados = np.unique(np.append(activos_con_peso, nuevos_activos))

   
    if len(activos_heredados) > num_act_max:

        seleccion_aleatoria = random.sample(range(len(activos_heredados)), len(activos_heredados))[0:20]
        activos_heredados = activos_heredados[seleccion_aleatoria]    

    return activos_heredados

# %%
def mutacion(datos_ordenados, activos_con_peso, num_act_max = 20):
    
   

    num_nuevos_activos = np.random.randint(low=1, high=4, size=1)

    nuevos_activos = np.random.randint(low=0, high=datos_ordenados.shape[1]-1, size=num_nuevos_activos)

    return nuevos_activos

# %% [markdown]
# ## Reemplazo generacional

# %%
def reemplazo_generacional(datos_ordenados, lista_posiciones, lista_fitness, lista_pesos_carteras_fitness, activos_cartera_mejor_individuo):

    '''
    La estrategia de reemplazo generacional que vamos a utilizar es reemplazo total. 
    La generación de hijos reemplaza a sus padres, a excepción del mejor de la generación anterior.
    '''
    
    
    matriz_descendencia = list()
    matriz_descendencia.append(activos_cartera_mejor_individuo)

    for hijo in range(len(lista_posiciones)-1):

    
        padres_seleccionados = seleccion_padres(lista_fitness)

        
        activos_heredados = cruzamiento(datos_ordenados, lista_posiciones, lista_pesos_carteras_fitness, padres_seleccionados, umbral = 0.4, num_act_max = 20)

       
        matriz_descendencia.append(activos_heredados)

    #la matriz de descendencia se ha de llamar lista_posiciones
    lista_posiciones = matriz_descendencia

    return lista_posiciones

# %% [markdown]
# ## Ejecutamos el algoritmo genético

# %%
datos_ordenados = cargar_datos()

# Generamos la población inicial
lista_posiciones = generar_poblacion_inicial(datos_ordenados, num_act_min = 2, num_act_max = 20)
fitness_mejor_individuo = 0
generaciones_sin_mejora = 0
generacion = 0

while generaciones_sin_mejora < 100:

    generacion += 1

    # Calculamos la función de fitness a la generación actual
    lista_fitness = list()
    lista_pesos_carteras_fitness =  list()
    for cartera in range(len(lista_posiciones)):

        fitness, pesos_fitness = calcular_fitness(datos_ordenados = datos_ordenados, posiciones = lista_posiciones[cartera])
        lista_fitness.append(fitness)
        lista_pesos_carteras_fitness.append(pesos_fitness)

    # Guardamos el mejor individuo de la generación actual
    if fitness_mejor_individuo < max(lista_fitness):

        fitness_mejor_individuo = max(lista_fitness)            
        posicion_mejor_individuo = np.where(lista_fitness == fitness_mejor_individuo)
        pesos_cartera_mejor_individuo = lista_pesos_carteras_fitness[posicion_mejor_individuo[0][0]]
        activos_cartera_mejor_individuo = lista_posiciones[posicion_mejor_individuo[0][0]]
        print(f'Generación {generacion}. El mejor individuo tiene una eficiencia de {fitness_mejor_individuo}')
        generaciones_sin_mejora = 0

    else:

        print(f'Generación {generacion+1}. Sin mejora generacional respecto a la anterior')
        generaciones_sin_mejora += 1

    # Llevamos a cabo la selección de padres, cruzamiento, mutación y matriz de descendencia
    lista_posiciones = reemplazo_generacional(datos_ordenados, lista_posiciones, lista_fitness, lista_pesos_carteras_fitness, activos_cartera_mejor_individuo)

print(fitness_mejor_individuo)
print(activos_cartera_mejor_individuo)
print(pesos_cartera_mejor_individuo)
# Out:
# Generación 1. El mejor individuo tiene una eficiencia de 0.3234185587483984
# Generación 2. El mejor individuo tiene una eficiencia de 0.3939207860840887
# Generación 3. El mejor individuo tiene una eficiencia de 0.42228106989080594
# Generación 4. El mejor individuo tiene una eficiencia de 0.4438165797570238
# Generación 6. Sin mejora generacional respecto a la anterior
# Generación 7. Sin mejora generacional respecto a la anterior
# Generación 8. Sin mejora generacional respecto a la anterior
# Generación 9. Sin mejora generacional respecto a la anterior
# Generación 9. El mejor individuo tiene una eficiencia de 0.4655786460113092
# Generación 10. El mejor individuo tiene una eficiencia de 0.4719314530172421
# Generación 11. El mejor individuo tiene una eficiencia de 0.48287069829374046
# Generación 12. El mejor individuo tiene una eficiencia de 0.4867779341017799
# Generación 14. Sin mejora generacional respecto a la anterior
# Generación 14. El mejor individuo tiene una eficiencia de 0.5121176667044909
# Generación 15. El mejor individuo tiene una eficiencia de 0.5136297215761645
# Generación 16. El mejor individuo tiene una eficiencia de 0.5332859192431083
# Generación 17. El mejor individuo tiene una eficiencia de 0.7393223747598853
# Generación 18. El mejor individuo tiene una eficiencia de 0.772126550562637
# Generación 19. El mejor individuo tiene una eficiencia de 0.7770791674363334
# Generación 20. El mejor individuo tiene una eficiencia de 0.7906116867574086
# Generación 21. El mejor individuo tiene una eficiencia de 0.7915153365791353
# Generación 23. Sin mejora generacional respecto a la anterior
# Generación 23. El mejor individuo tiene una eficiencia de 0.8044686502666897
# Generación 25. Sin mejora generacional respecto a la anterior
# Generación 26. Sin mejora generacional respecto a la anterior
# Generación 27. Sin mejora generacional respecto a la anterior
# Generación 27. El mejor individuo tiene una eficiencia de 0.8058884262615029
# Generación 29. Sin mejora generacional respecto a la anterior
# Generación 30. Sin mejora generacional respecto a la anterior
# Generación 31. Sin mejora generacional respecto a la anterior
# Generación 32. Sin mejora generacional respecto a la anterior
# Generación 33. Sin mejora generacional respecto a la anterior
# Generación 34. Sin mejora generacional respecto a la anterior
# Generación 35. Sin mejora generacional respecto a la anterior
# Generación 36. Sin mejora generacional respecto a la anterior
# Generación 37. Sin mejora generacional respecto a la anterior
# Generación 38. Sin mejora generacional respecto a la anterior
# Generación 39. Sin mejora generacional respecto a la anterior
# Generación 40. Sin mejora generacional respecto a la anterior
# Generación 41. Sin mejora generacional respecto a la anterior
# Generación 42. Sin mejora generacional respecto a la anterior
# Generación 43. Sin mejora generacional respecto a la anterior
# Generación 44. Sin mejora generacional respecto a la anterior
# Generación 45. Sin mejora generacional respecto a la anterior
# Generación 46. Sin mejora generacional respecto a la anterior
# Generación 47. Sin mejora generacional respecto a la anterior
# Generación 48. Sin mejora generacional respecto a la anterior
# Generación 49. Sin mejora generacional respecto a la anterior
# Generación 50. Sin mejora generacional respecto a la anterior
# Generación 51. Sin mejora generacional respecto a la anterior
# Generación 52. Sin mejora generacional respecto a la anterior
# Generación 53. Sin mejora generacional respecto a la anterior
# Generación 54. Sin mejora generacional respecto a la anterior
# Generación 55. Sin mejora generacional respecto a la anterior
# Generación 56. Sin mejora generacional respecto a la anterior
# Generación 57. Sin mejora generacional respecto a la anterior
# Generación 58. Sin mejora generacional respecto a la anterior
# Generación 59. Sin mejora generacional respecto a la anterior
# Generación 60. Sin mejora generacional respecto a la anterior
# Generación 61. Sin mejora generacional respecto a la anterior
# Generación 62. Sin mejora generacional respecto a la anterior
# Generación 63. Sin mejora generacional respecto a la anterior
# Generación 64. Sin mejora generacional respecto a la anterior
# Generación 65. Sin mejora generacional respecto a la anterior
# Generación 66. Sin mejora generacional respecto a la anterior
# Generación 67. Sin mejora generacional respecto a la anterior
# Generación 68. Sin mejora generacional respecto a la anterior
# Generación 69. Sin mejora generacional respecto a la anterior
# Generación 70. Sin mejora generacional respecto a la anterior
# Generación 71. Sin mejora generacional respecto a la anterior
# Generación 72. Sin mejora generacional respecto a la anterior
# Generación 72. El mejor individuo tiene una eficiencia de 0.8212621042751623
# Generación 74. Sin mejora generacional respecto a la anterior
# Generación 75. Sin mejora generacional respecto a la anterior
# Generación 76. Sin mejora generacional respecto a la anterior
# Generación 77. Sin mejora generacional respecto a la anterior
# Generación 77. El mejor individuo tiene una eficiencia de 0.8452761338168484
# Generación 79. Sin mejora generacional respecto a la anterior
# Generación 80. Sin mejora generacional respecto a la anterior
# Generación 80. El mejor individuo tiene una eficiencia de 0.8765976468092451
# Generación 82. Sin mejora generacional respecto a la anterior
# Generación 82. El mejor individuo tiene una eficiencia de 0.8910932568250531
# Generación 84. Sin mejora generacional respecto a la anterior
# Generación 85. Sin mejora generacional respecto a la anterior
# Generación 86. Sin mejora generacional respecto a la anterior
# Generación 87. Sin mejora generacional respecto a la anterior
# Generación 88. Sin mejora generacional respecto a la anterior
# Generación 89. Sin mejora generacional respecto a la anterior
# Generación 90. Sin mejora generacional respecto a la anterior
# Generación 90. El mejor individuo tiene una eficiencia de 0.891291750447947
# Generación 92. Sin mejora generacional respecto a la anterior
# Generación 93. Sin mejora generacional respecto a la anterior
# Generación 94. Sin mejora generacional respecto a la anterior
# Generación 95. Sin mejora generacional respecto a la anterior
# Generación 96. Sin mejora generacional respecto a la anterior
# Generación 97. Sin mejora generacional respecto a la anterior
# Generación 98. Sin mejora generacional respecto a la anterior
# Generación 98. El mejor individuo tiene una eficiencia de 1.0852997561064723
# Generación 100. Sin mejora generacional respecto a la anterior
# Generación 100. El mejor individuo tiene una eficiencia de 1.1480642204483416
# Generación 101. El mejor individuo tiene una eficiencia de 1.1541662467712788
# Generación 103. Sin mejora generacional respecto a la anterior
# Generación 104. Sin mejora generacional respecto a la anterior
# Generación 105. Sin mejora generacional respecto a la anterior
# Generación 106. Sin mejora generacional respecto a la anterior
# Generación 107. Sin mejora generacional respecto a la anterior
# Generación 108. Sin mejora generacional respecto a la anterior
# Generación 108. El mejor individuo tiene una eficiencia de 1.1549619546890737
# Generación 110. Sin mejora generacional respecto a la anterior
# Generación 111. Sin mejora generacional respecto a la anterior
# Generación 112. Sin mejora generacional respecto a la anterior
# Generación 113. Sin mejora generacional respecto a la anterior
# Generación 114. Sin mejora generacional respecto a la anterior
# Generación 115. Sin mejora generacional respecto a la anterior
# Generación 116. Sin mejora generacional respecto a la anterior
# Generación 117. Sin mejora generacional respecto a la anterior
# Generación 118. Sin mejora generacional respecto a la anterior
# Generación 119. Sin mejora generacional respecto a la anterior
# Generación 120. Sin mejora generacional respecto a la anterior
# Generación 121. Sin mejora generacional respecto a la anterior
# Generación 122. Sin mejora generacional respecto a la anterior
# Generación 123. Sin mejora generacional respecto a la anterior
# Generación 124. Sin mejora generacional respecto a la anterior
# Generación 124. El mejor individuo tiene una eficiencia de 1.164383877277004
# Generación 126. Sin mejora generacional respecto a la anterior
# Generación 127. Sin mejora generacional respecto a la anterior
# Generación 128. Sin mejora generacional respecto a la anterior
# Generación 129. Sin mejora generacional respecto a la anterior
# Generación 130. Sin mejora generacional respecto a la anterior
# Generación 131. Sin mejora generacional respecto a la anterior
# Generación 131. El mejor individuo tiene una eficiencia de 1.1684953958254911
# Generación 133. Sin mejora generacional respecto a la anterior
# Generación 134. Sin mejora generacional respecto a la anterior
# Generación 135. Sin mejora generacional respecto a la anterior
# Generación 136. Sin mejora generacional respecto a la anterior
# Generación 137. Sin mejora generacional respecto a la anterior
# Generación 138. Sin mejora generacional respecto a la anterior
# Generación 139. Sin mejora generacional respecto a la anterior
# Generación 140. Sin mejora generacional respecto a la anterior
# Generación 141. Sin mejora generacional respecto a la anterior
# Generación 142. Sin mejora generacional respecto a la anterior
# Generación 143. Sin mejora generacional respecto a la anterior
# Generación 144. Sin mejora generacional respecto a la anterior
# Generación 145. Sin mejora generacional respecto a la anterior
# Generación 146. Sin mejora generacional respecto a la anterior
# Generación 147. Sin mejora generacional respecto a la anterior
# Generación 148. Sin mejora generacional respecto a la anterior
# Generación 149. Sin mejora generacional respecto a la anterior
# Generación 150. Sin mejora generacional respecto a la anterior
# Generación 151. Sin mejora generacional respecto a la anterior
# Generación 152. Sin mejora generacional respecto a la anterior
# Generación 153. Sin mejora generacional respecto a la anterior
# Generación 153. El mejor individuo tiene una eficiencia de 1.1733690796198888
# Generación 155. Sin mejora generacional respecto a la anterior
# Generación 155. El mejor individuo tiene una eficiencia de 1.18508846240965
# Generación 157. Sin mejora generacional respecto a la anterior
# Generación 157. El mejor individuo tiene una eficiencia de 1.1851310291109212
# Generación 158. El mejor individuo tiene una eficiencia de 1.185187595607989
# Generación 160. Sin mejora generacional respecto a la anterior
# Generación 161. Sin mejora generacional respecto a la anterior
# Generación 162. Sin mejora generacional respecto a la anterior
# Generación 163. Sin mejora generacional respecto a la anterior
# Generación 164. Sin mejora generacional respecto a la anterior
# Generación 164. El mejor individuo tiene una eficiencia de 1.2350415387918148
# Generación 166. Sin mejora generacional respecto a la anterior
# Generación 166. El mejor individuo tiene una eficiencia de 1.2798181473601014
# Generación 168. Sin mejora generacional respecto a la anterior
# Generación 169. Sin mejora generacional respecto a la anterior
# Generación 170. Sin mejora generacional respecto a la anterior
# Generación 171. Sin mejora generacional respecto a la anterior
# Generación 171. El mejor individuo tiene una eficiencia de 1.280883850996486
# Generación 173. Sin mejora generacional respecto a la anterior
# Generación 173. El mejor individuo tiene una eficiencia de 1.2845222555745608
# Generación 175. Sin mejora generacional respecto a la anterior
# Generación 176. Sin mejora generacional respecto a la anterior
# Generación 177. Sin mejora generacional respecto a la anterior
# Generación 178. Sin mejora generacional respecto a la anterior
# Generación 178. El mejor individuo tiene una eficiencia de 1.2873223109557326
# Generación 180. Sin mejora generacional respecto a la anterior
# Generación 181. Sin mejora generacional respecto a la anterior
# Generación 182. Sin mejora generacional respecto a la anterior
# Generación 183. Sin mejora generacional respecto a la anterior
# Generación 184. Sin mejora generacional respecto a la anterior
# Generación 185. Sin mejora generacional respecto a la anterior
# Generación 186. Sin mejora generacional respecto a la anterior
# Generación 187. Sin mejora generacional respecto a la anterior
# Generación 188. Sin mejora generacional respecto a la anterior
# Generación 189. Sin mejora generacional respecto a la anterior
# Generación 190. Sin mejora generacional respecto a la anterior
# Generación 191. Sin mejora generacional respecto a la anterior
# Generación 192. Sin mejora generacional respecto a la anterior
# Generación 193. Sin mejora generacional respecto a la anterior
# Generación 194. Sin mejora generacional respecto a la anterior
# Generación 195. Sin mejora generacional respecto a la anterior
# Generación 196. Sin mejora generacional respecto a la anterior
# Generación 197. Sin mejora generacional respecto a la anterior
# Generación 198. Sin mejora generacional respecto a la anterior
# Generación 199. Sin mejora generacional respecto a la anterior
# Generación 200. Sin mejora generacional respecto a la anterior
# Generación 201. Sin mejora generacional respecto a la anterior
# Generación 202. Sin mejora generacional respecto a la anterior
# Generación 203. Sin mejora generacional respecto a la anterior
# Generación 204. Sin mejora generacional respecto a la anterior
# Generación 205. Sin mejora generacional respecto a la anterior
# Generación 206. Sin mejora generacional respecto a la anterior
# Generación 207. Sin mejora generacional respecto a la anterior
# Generación 208. Sin mejora generacional respecto a la anterior
# Generación 209. Sin mejora generacional respecto a la anterior
# Generación 210. Sin mejora generacional respecto a la anterior
# Generación 211. Sin mejora generacional respecto a la anterior
# Generación 212. Sin mejora generacional respecto a la anterior
# Generación 213. Sin mejora generacional respecto a la anterior
# Generación 214. Sin mejora generacional respecto a la anterior
# Generación 215. Sin mejora generacional respecto a la anterior
# Generación 216. Sin mejora generacional respecto a la anterior
# Generación 217. Sin mejora generacional respecto a la anterior
# Generación 218. Sin mejora generacional respecto a la anterior
# Generación 219. Sin mejora generacional respecto a la anterior
# Generación 220. Sin mejora generacional respecto a la anterior
# Generación 221. Sin mejora generacional respecto a la anterior
# Generación 222. Sin mejora generacional respecto a la anterior
# Generación 223. Sin mejora generacional respecto a la anterior
# Generación 224. Sin mejora generacional respecto a la anterior
# Generación 225. Sin mejora generacional respecto a la anterior
# Generación 226. Sin mejora generacional respecto a la anterior
# Generación 227. Sin mejora generacional respecto a la anterior
# Generación 228. Sin mejora generacional respecto a la anterior
# Generación 229. Sin mejora generacional respecto a la anterior
# Generación 230. Sin mejora generacional respecto a la anterior
# Generación 231. Sin mejora generacional respecto a la anterior
# Generación 232. Sin mejora generacional respecto a la anterior
# Generación 233. Sin mejora generacional respecto a la anterior
# Generación 234. Sin mejora generacional respecto a la anterior
# Generación 235. Sin mejora generacional respecto a la anterior
# Generación 236. Sin mejora generacional respecto a la anterior
# Generación 237. Sin mejora generacional respecto a la anterior
# Generación 238. Sin mejora generacional respecto a la anterior
# Generación 239. Sin mejora generacional respecto a la anterior
# Generación 240. Sin mejora generacional respecto a la anterior
# Generación 241. Sin mejora generacional respecto a la anterior
# Generación 242. Sin mejora generacional respecto a la anterior
# Generación 243. Sin mejora generacional respecto a la anterior
# Generación 244. Sin mejora generacional respecto a la anterior
# Generación 245. Sin mejora generacional respecto a la anterior
# Generación 246. Sin mejora generacional respecto a la anterior
# Generación 247. Sin mejora generacional respecto a la anterior
# Generación 248. Sin mejora generacional respecto a la anterior
# Generación 249. Sin mejora generacional respecto a la anterior
# Generación 250. Sin mejora generacional respecto a la anterior
# Generación 251. Sin mejora generacional respecto a la anterior
# Generación 252. Sin mejora generacional respecto a la anterior
# Generación 253. Sin mejora generacional respecto a la anterior
# Generación 254. Sin mejora generacional respecto a la anterior
# Generación 255. Sin mejora generacional respecto a la anterior
# Generación 256. Sin mejora generacional respecto a la anterior
# Generación 257. Sin mejora generacional respecto a la anterior
# Generación 258. Sin mejora generacional respecto a la anterior
# Generación 259. Sin mejora generacional respecto a la anterior
# Generación 260. Sin mejora generacional respecto a la anterior
# Generación 261. Sin mejora generacional respecto a la anterior
# Generación 262. Sin mejora generacional respecto a la anterior
# Generación 263. Sin mejora generacional respecto a la anterior
# Generación 264. Sin mejora generacional respecto a la anterior
# Generación 265. Sin mejora generacional respecto a la anterior
# Generación 266. Sin mejora generacional respecto a la anterior
# Generación 267. Sin mejora generacional respecto a la anterior
# Generación 268. Sin mejora generacional respecto a la anterior
# Generación 269. Sin mejora generacional respecto a la anterior
# Generación 270. Sin mejora generacional respecto a la anterior
# Generación 271. Sin mejora generacional respecto a la anterior
# Generación 272. Sin mejora generacional respecto a la anterior
# Generación 273. Sin mejora generacional respecto a la anterior
# Generación 274. Sin mejora generacional respecto a la anterior
# Generación 275. Sin mejora generacional respecto a la anterior
# Generación 276. Sin mejora generacional respecto a la anterior
# Generación 277. Sin mejora generacional respecto a la anterior
# Generación 278. Sin mejora generacional respecto a la anterior
# Generación 279. Sin mejora generacional respecto a la anterior
# 1.2873223109557326
# [22808 32953 39048 39070 48011 56525]
# [[[0.06846977 0.         0.14204205 0.5223331  0.26715509 0.        ]]]

# %%
print(fitness_mejor_individuo)
print(activos_cartera_mejor_individuo)
print(pesos_cartera_mejor_individuo)
# Out:
# 1.2873223109557326
# [22808 32953 39048 39070 48011 56525]
# [[[0.06846977 0.         0.14204205 0.5223331  0.26715509 0.        ]]]

# %%
print(fitness_mejor_individuo)
print(activos_cartera_mejor_individuo)
print(pesos_cartera_mejor_individuo)
# Out:
# 1.2873223109557326
# [22808 32953 39048 39070 48011 56525]
# [[[0.06846977 0.         0.14204205 0.5223331  0.26715509 0.        ]]]

# %%
print(fitness_mejor_individuo)
print(activos_cartera_mejor_individuo)
print(pesos_cartera_mejor_individuo)
# Out:
# 1.2873223109557326
# [22808 32953 39048 39070 48011 56525]
# [[[0.06846977 0.         0.14204205 0.5223331  0.26715509 0.        ]]]
